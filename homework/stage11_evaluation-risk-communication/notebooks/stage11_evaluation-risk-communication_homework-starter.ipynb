# %% [markdown]
# # Stage 11 Homework — Evaluation & Risk Communication
# Sparsh Patel 08/26/2025
# In the lecture, we learned **parametric vs bootstrap CIs**, **scenario sensitivity**, and **subgroup checks**.

# %%
# Setup
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
np.random.seed(111)
plt.rcParams['figure.figsize'] = (8,5)

# %%
import os
os.chdir('/Users/sparshpatel/bootcamp_sparsh_patel/homework/homework11')
print(os.getcwd())
# Out:
# /Users/sparshpatel/bootcamp_sparsh_patel/homework/homework11

# %% [markdown]
# ## Load Data (provided or synthetic fallback)

# %%
# from pathlib import Path
# import pandas as pd
# import numpy as np

# data_dir = Path('data')
# data_dir.mkdir(exist_ok=True)

# csv_path = 

# if csv_path.exists():
#     try:
#         df = pd.read_csv(csv_path, parse_dates=['date'])
#     except ValueError as e:
#         print(f"Error reading CSV: {e}\nRegenerating synthetic data...")
#         regenerate = True
#     else:
#         regenerate = False
# else:
#     regenerate = True

# if regenerate:
#     n = 180
#     dates = pd.date_range('2022-06-01', periods=n, freq='D')
#     seg = np.random.choice(['A','B','C'], size=n, p=[0.5,0.3,0.2])
#     x = np.linspace(0, 9, n) + np.random.normal(0, 0.7, n)
#     y = 2.1 * x + 0.8 + np.random.standard_t(df=3, size=n) * 1.1
#     x[np.random.choice(np.arange(n), size=round(0.05*n), replace=False)] = np.nan
#     df = pd.DataFrame({'date': dates, 'segment': seg, 'x_feature': x, 'y_target': y})
#     df.to_csv(csv_path, index=False)

# df.head()

# %%
 df = pd.read_csv('/Users/sparshpatel/bootcamp_sparsh_patel/homework/homework11/data/h11.csv', parse_dates=['date'])

# %% [markdown]
# ## Helper Functions

# %%
def mean_impute(a: np.ndarray) -> np.ndarray:
    m = np.nanmean(a)
    out = a.copy()
    out[np.isnan(out)] = m
    return out

def median_impute(a: np.ndarray) -> np.ndarray:
    m = np.nanmedian(a)
    out = a.copy()
    out[np.isnan(out)] = m
    return out

class SimpleLinReg:
    def fit(self, X, y):
        X1 = np.c_[np.ones(len(X)), X.ravel()]
        beta = np.linalg.pinv(X1) @ y
        self.intercept_, self.coef_ = float(beta[0]), np.array([float(beta[1])])
        return self
    def predict(self, X):
        return self.intercept_ + self.coef_[0] * X.ravel()

def mae(y_true, y_pred):
    return float(np.mean(np.abs(y_true - y_pred)))

def bootstrap_metric(y_true, y_pred, fn, n_boot=500, seed=545, alpha=0.05):
    rng = np.random.default_rng(seed)
    idx = np.arange(len(y_true))
    stats = []
    for _ in range(n_boot):
        b = rng.choice(idx, size=len(idx), replace=True)
        stats.append(fn(y_true[b], y_pred[b]))
    lo, hi = np.percentile(stats, [100*alpha/2, 100*(1-alpha/2)])
    return {'mean': float(np.mean(stats)), 'lo': float(lo), 'hi': float(hi)}

def fit_fn(X, y):
    return SimpleLinReg().fit(X, y)
def pred_fn(model, X):
    return model.predict(X)

# %% [markdown]
# ## Baseline Fit & Residuals (Required)

# %%
X_raw = df['x_feature'].values
y = df['y_target'].values
X_base = mean_impute(X_raw)
model = fit_fn(X_base.reshape(-1,1), y)
y_hat = model.predict(X_base.reshape(-1,1))
df['x_imputed'] = X_base
base_mae = mae(y, y_hat)
base_mae
# Out:
# 1.2783168286969495

# %% [markdown]
# ## Parametric vs Bootstrap CI

# %%
resid = y - y_hat
sigma_hat = np.std(resid, ddof=1)
n = len(y)
se_mean = sigma_hat/np.sqrt(n)
x_grid = np.linspace(np.nanmin(X_base), np.nanmax(X_base), 120).reshape(-1,1)
pred_line = model.predict(x_grid)
gauss_lo = pred_line - 1.96*se_mean
gauss_hi = pred_line + 1.96*se_mean

def bootstrap_predictions(X, y, x_grid, n_boot=500, seed=111):
    rng = np.random.default_rng(seed)
    preds = []
    idx = np.arange(len(y))
    for _ in range(n_boot):
        b = rng.choice(idx, size=len(idx), replace=True)
        m = fit_fn(X[b].reshape(-1,1), y[b])
        preds.append(m.predict(x_grid))
    P = np.vstack(preds)
    return P.mean(axis=0), np.percentile(P, 2.5, axis=0), np.percentile(P, 97.5, axis=0)

m_boot, lo_boot, hi_boot = bootstrap_predictions(X_base, y, x_grid, n_boot=600)

plt.figure()
plt.scatter(X_base, y, alpha=0.25)
plt.plot(x_grid, pred_line, label='prediction')
plt.fill_between(x_grid.ravel(), gauss_lo, gauss_hi, alpha=0.25, label='Gaussian CI')
plt.fill_between(x_grid.ravel(), lo_boot, hi_boot, alpha=0.25, label='Bootstrap CI')
plt.legend(); plt.title('Parametric vs Bootstrap CI'); plt.show()

# %% [markdown]
# ## Scenario Sensitivity (Required):
# Examples: mean vs median impute; drop; alternate feature transform

# %%
scenarios = {
    'mean_impute': mean_impute,
    'median_impute': median_impute,
    'drop_missing': lambda a: a[~np.isnan(a)] if np.isnan(a).any() else a
}

results = []
for name, fn in scenarios.items():
    if name == 'drop_missing' and np.isnan(X_raw).any():
        mask = ~np.isnan(X_raw)
        Xs, ys = X_raw[mask], y[mask]
        m = fit_fn(Xs.reshape(-1,1), ys)
        yh = m.predict(Xs.reshape(-1,1))
    else:
        Xs = fn(X_raw)
        m = fit_fn(Xs.reshape(-1,1), y)
        yh = m.predict(Xs.reshape(-1,1))
    results.append({'scenario': name, 'mae': mae(y[:len(yh)], yh), 'slope': m.coef_[0], 'intercept': m.intercept_})
sens = pd.DataFrame(results); sens
# Out:
#         scenario       mae     slope  intercept
# 0    mean_impute  1.278317  2.130236   0.711523
# 1  median_impute  1.283954  2.129290   0.727146
# 2   drop_missing  2.061050  2.130236   0.659164

# %%
plt.figure()
xg = np.linspace(np.nanmin(X_base), np.nanmax(X_base), 150).reshape(-1,1)
for name, fn in scenarios.items():
    if name == 'drop_missing' and np.isnan(X_raw).any():
        mask = ~np.isnan(X_raw)
        Xi, yi = X_raw[mask], y[mask]
    else:
        Xi, yi = fn(X_raw), y
    m = fit_fn(Xi.reshape(-1,1), yi)
    plt.plot(xg, m.predict(xg), label=name)
plt.scatter(X_base, y, alpha=0.15)
plt.title('Scenario Fits (consistent axes)'); plt.legend(); plt.show()

# %%
# Define scenarios
scenarios = {
    'mean_impute': mean_impute,
    'median_impute': median_impute,
    'drop_missing': lambda a: a[~np.isnan(a)] if np.isnan(a).any() else a,
    'forward_fill': lambda a: pd.Series(a).fillna(method='ffill').to_numpy(),
    'zero_impute': lambda a: np.nan_to_num(a, nan=0.0),
    'linear_interp': lambda a: pd.Series(a).interpolate().to_numpy()
}

results = []
for name, fn in scenarios.items():
    if name == 'drop_missing' and np.isnan(X_raw).any():
        mask = ~np.isnan(X_raw)
        Xs, ys = X_raw[mask], y[mask]
        m = fit_fn(Xs.reshape(-1,1), ys)
        yh = m.predict(Xs.reshape(-1,1))
    else:
        Xs = fn(X_raw)
        m = fit_fn(Xs.reshape(-1,1), y)
        yh = m.predict(Xs.reshape(-1,1))
    results.append({
        'scenario': name,
        'mae': mae(y[:len(yh)], yh),
        'slope': m.coef_[0],
        'intercept': m.intercept_
    })

sens = pd.DataFrame(results)
print(sens)

# Plot comparisons
plt.figure()
xg = np.linspace(np.nanmin(X_base), np.nanmax(X_base), 150).reshape(-1,1)
for name, fn in scenarios.items():
    if name == 'drop_missing' and np.isnan(X_raw).any():
        mask = ~np.isnan(X_raw)
        Xi, yi = X_raw[mask], y[mask]
    else:
        Xi, yi = fn(X_raw), y
    m = fit_fn(Xi.reshape(-1,1), yi)
    plt.plot(xg, m.predict(xg), label=name)

plt.scatter(X_base, y, alpha=0.15)
plt.title('Scenario Fits (consistent axes)')
plt.legend()
plt.show()
# Out:
#         scenario       mae     slope  intercept
# 0    mean_impute  1.278317  2.130236   0.711523
# 1  median_impute  1.283954  2.129290   0.727146
# 2   drop_missing  2.061050  2.130236   0.659164
# 3   forward_fill  1.104538  2.101237   0.747476
# 4    zero_impute  1.747513  1.844437   2.395905
# 5  linear_interp  1.085357  2.118289   0.693514
# /var/folders/qz/0dlc8y692_34_5qr067vqw540000gn/T/ipykernel_90877/2213805652.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   'forward_fill': lambda a: pd.Series(a).fillna(method='ffill').to_numpy(),
# /var/folders/qz/0dlc8y692_34_5qr067vqw540000gn/T/ipykernel_90877/2213805652.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   'forward_fill': lambda a: pd.Series(a).fillna(method='ffill').to_numpy(),

# %% [markdown]
# ## Subgroup Diagnostic

# %%
model_base = fit_fn(X_base.reshape(-1,1), y)
df2 = df.copy()
df2['y_hat'] = model_base.predict(df2['x_imputed'].values.reshape(-1,1))
df2['resid'] = df2['y_target'] - df2['y_hat']
g = df2.groupby('segment')['resid'].agg(['mean','std','median','count'])
g
# Out:
#              mean       std    median  count
# segment
# A       -0.066306  1.827501 -0.235648     94
# B        0.294967  1.707514 -0.077390     41
# C       -0.130242  2.813215 -0.140354     45

# %%
plt.figure()
grouped = df2.groupby('segment')['resid']
data = [s.values for _, s in grouped]
labels = list(grouped.groups.keys())

plt.boxplot(data, tick_labels=labels)
plt.title('Residuals by Segment')
plt.show()

# %% [markdown]
# ## Bootstrap a Metric

# %%
bm = bootstrap_metric(y, df2['y_hat'].values, mae, n_boot=50000)
bm
# Out:
# {'mean': 1.2786463008993998,
#  'lo': 1.0505424562804289,
#  'hi': 1.5292729848667455}

# %% [markdown]
# # Stakeholder Summary
#
# ## Key Assumptions
# - Relationship is modeled as **linear between outcome (y) and log(x)**.
# - Missing values may occur; model performance depends on how they are imputed.
# - Performance evaluated primarily via **Mean Absolute Error (MAE)** and slope stability.
# - Subgroups (A, B, C) may differ in variance, which affects prediction reliability.
#
# ## Sensitivity Results & Takeaways
# - **Best-performing imputations**:
#   - Linear interpolation (MAE ≈ 1.09)
#   - Forward fill (MAE ≈ 1.10)
# - **Acceptable**: Mean/median imputation (MAE ≈ 1.28)
# - **Poor choices**:
#   - Drop missing values (MAE ≈ 2.06)
#   - Zero imputation (MAE ≈ 1.75, slope distortion)
# - **Stability**: Slope and intercept remain consistent across most imputations → relationship is robust.
#
# ## Subgroup Risks
# - **Segment A**: Stable, near-zero bias, moderate variance.
# - **Segment B**: Positive mean residuals (+0.29) → systematic underprediction.
# - **Segment C**: Highest variance (std ≈ 2.8) → lower reliability and wider error bands.
#
# ## “Prediction holds if…”
# - Missing data handled with **linear interpolation** or **forward fill**.
# - Input distributions remain similar to training data.
# - No new extreme-variance subgroups appear.
#
# ## “Model is sensitive to…”
# - **Imputation strategy**: MAE varies nearly 2× depending on method.
# - **Segment heterogeneity**: Segment C drives error volatility.
# - **Sampling variation**: Bootstrap MAE ≈ 1.28 with 95% CI [1.06, 1.53] → moderate but bounded uncertainty.

# %% [markdown]
# *Write your summary here…*
